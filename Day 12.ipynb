# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nandeesh\\Untitled Folder 2'

# %%
dataset=pd.read_csv("general_data.csv")
dataset1=dataset[dataset["Attrition"] =="Yes"]
dataset1.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 1    31       Yes  Travel_Frequently  Research & Development
# 6    28       Yes      Travel_Rarely  Research & Development
# 13   47       Yes         Non-Travel  Research & Development
# 28   44       Yes  Travel_Frequently  Research & Development
# 30   26       Yes      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
# wilcoxon test
from scipy.stats import wilcoxon
stats,p=wilcoxon(dataset1.TrainingTimesLastYear,dataset1.YearsAtCompany)
print(stats,p)
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 63369.0 7.4007966521884e-21
# Reject null hypothesis

# %%
# friedman test
from scipy.stats import friedmanchisquare
stats,p=friedmanchisquare(dataset1.TrainingTimesLastYear,dataset1.YearsAtCompany,dataset1.YearsSinceLastPromotion)
print(stats,p)
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 525.9236111111114 6.26814300144918e-115
# Reject null hypothesis

# %%
6.26814300144918e-50
# Out:
# 6.26814300144918e-50

# %%
dataset=pd.read_csv("general_data.csv")
dataset2=dataset[dataset["Attrition"] =="No"]
dataset2.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
# 5          3  Life Sciences              1           6  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
# mannwhitney test
from scipy.stats import mannwhitneyu
stats,p=mannwhitneyu(dataset1.DistanceFromHome,dataset2.DistanceFromHome)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition and distance from home.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 1312110.0 0.4629185205822659
# Accept null hypothesis

# %%
# kruskal willis test
from scipy.stats import kruskal
stats,p=kruskal(dataset1.DistanceFromHome,dataset2.DistanceFromHome,dataset1.Education)
print(stats,p)
#Null Hypothesis:there is no significance difference between attrition, distance from home and education.
if p<0.05:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# 357.00124900231907 3.007210041382896e-78
# Reject null hypothesis

# %%
# chisquare
dataset3=dataset.dropna()
dataset3.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
from scipy.stats import chi2_contingency
chitable=pd.crosstab(dataset3.Attrition,dataset3.Gender)
chitable
# Out:
# Gender     Female  Male
# Attrition
# No           1488  2189
# Yes           268   437

# %%
stats,p,dof,expected=chi2_contingency(chitable)
print(stats,p)
#There is no significance difference between attrition and gender
if p<0.05:
    print("Reject Null hypothesis")
else:  
    print("Accept Null hypothesis")
# Out:
# 1.3825823839528295 0.23966176275638887
# Accept Null hypothesis

# %%
# one sample test
dataset1["Education"]
# Out:
# 1       1
# 6       2
# 13      1
# 28      2
# 30      3
#        ..
# 4381    1
# 4386    4
# 4388    3
# 4391    1
# 4402    3
# Name: Education, Length: 711, dtype: int64

# %%
from scipy.stats import ttest_1samp
stats,p=ttest_1samp(dataset1.Education,5)
print(stats,p)
#there is no significance difference between mean of Education and population mean=5
if p<0.05:
    print("Reject Null hypothesis")
else:
    print("Accept Null hypothesis")
# Out:
# -55.79776195180027 8.873147476482694e-262
# Reject Null hypothesis

# %%
# two sample paired testprint
(dataset1["DistanceFromHome"],dataset1["Education"])
# Out:
# (1       10
#  6       11
#  13       1
#  28       1
#  30       4
#          ..
#  4381     7
#  4386    11
#  4388     1
#  4391    23
#  4402     2
#  Name: DistanceFromHome, Length: 711, dtype: int64,
#  1       1
#  6       2
#  13      1
#  28      2
#  30      3
#         ..
#  4381    1
#  4386    4
#  4388    3
#  4391    1
#  4402    3
#  Name: Education, Length: 711, dtype: int64)

# %%
from scipy.stats import ttest_rel
stats,p=ttest_rel(dataset1.Education,dataset1.DistanceFromHome)
print(stats,p)
#there is no significance difference between mean of Education and mean of distance from home.
if p<0.05:
    print("Reject Null hypothesis")
else:
    print("Accept Null hypothesis")
# Out:
# -20.98819117344752 1.840998337817305e-76
# Reject Null hypothesis

# %%
# Two sample independent test
dataset4=dataset.loc[dataset["Attrition"]=="Yes"]
dataset4.Attrition=dataset4.Attrition.map({"Yes":1})
dataset4.head()
# Out:
# C:\Users\nandeesh\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#     Age  Attrition     BusinessTravel              Department  \
# 1    31          1  Travel_Frequently  Research & Development
# 6    28          1      Travel_Rarely  Research & Development
# 13   47          1         Non-Travel  Research & Development
# 28   44          1  Travel_Frequently  Research & Development
# 30   26          1      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# ...

# %%
dataset5=dataset.loc[dataset["Attrition"]=="No"]
dataset5.Attrition=dataset5.Attrition.map({"No":0})
dataset5.head()
# Out:
# C:\Users\nandeesh\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
# 5   46          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# ...

# %%
from scipy.stats import ttest_ind
stats,p=ttest_ind(dataset4.Education,dataset5.Education)
print(stats,p)
#there is no significance difference between Attrition and mean of Education with respect to attrition yes or no.
if p<0.05:
    print("Reject Null hypothesis")
else:
    print("Accept Null hypothesis")
# Out:
# -1.003386859630148 0.3157293177122392
# Accept Null hypothesis
